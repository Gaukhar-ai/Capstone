# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaukhar-ai/Capstone/blob/master/Untitled30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''!pip install alpaca-trade-api --quiet
# !pip install pandas-ta --quiet
# !pip install -U git+https://github.com/twopirllc/pandas-ta'''
# Out:
# '!pip install alpaca-trade-api --quiet\n!pip install pandas-ta --quiet\n!pip install -U git+https://github.com/twopirllc/pandas-ta'

# %%
'''!wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# !tar -xzvf ta-lib-0.4.0-src.tar.gz
# %cd ta-lib
# !./configure --prefix=/usr
# !make
# !make install
# !pip install Ta-Lib
import talib'''
# Out:
# '!wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz\n!tar -xzvf ta-lib-0.4.0-src.tar.gz\n%cd ta-lib\n!./configure --prefix=/usr\n!make\n!make install\n!pip install Ta-Lib\nimport talib'

# %%
import alpaca_trade_api as tradeapi
import pandas as pd
import pandas_ta as ta
from pandas_datareader import data
import matplotlib.pyplot as plt
import time
import datetime
import threading
from pandas_ta.utils import get_drift, get_offset, verify_series
import talib

import numpy as np
import pandas as pd
from sklearn.preprocessing import scale
from scipy.spatial.distance import pdist, squareform
import seaborn as sns
# %matplotlib inline
from sklearn.mixture import GaussianMixture
#run kmeans and gaussian and interpret, keep how many clusters i need and change
import scipy
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.decomposition import PCA
from scipy.special import entr
import plotly.express as px
from sklearn import preprocessing
from sklearn import metrics 
from scipy.spatial.distance import cdist
from mpl_toolkits.mplot3d import Axes3D
robust_scaler = RobustScaler()
#X_train_robust = robust_scaler.fit_transform(df)

api = tradeapi.REST(key_id='PK4MC4MS4RI64GOEK0Y3', 
                    secret_key='Nt2HbEvo0aoozI5cS22sggRnSKmv22dB1wVVAEZo', 
                    base_url='https://paper-api.alpaca.markets')

# %%
# define timezome and time period
NY = 'America/New_York'
start=pd.Timestamp('2020-01-01', tz=NY).isoformat()
end=pd.Timestamp('2020-10-30', tz=NY).isoformat()

# %%
#stockUniverse = [
df = api.get_barset([
#stocks traded by me and skyrocketing ones.                  
'GE', 'F', 'AMZN', 'TSLA', 'AAPL', 'SNAP', 'GM', 'SHOP', 'TWTR', 'AMD', 'NVDA', 'FB',
#OIL COMPANIES:
'AXAS', 'BRY', 'CRZO', 'CDEV', 'DWSN', 'FANG', 'DMLP', 'EPSN', 'FLMN', 'GPOR', 'LLEX', 'LONE', 'BP',
'MARPS', 'MCEP', 'NEXT', 'PTEN', 'PDCE', 'PVAC', 'PNRG', 'RGCO', 'ROSE', 'SAEX', 'SNDE', 'TELL', 'TRCH', 'TGA', 'USEG', 'VNOM',
#PRECIOUS METALS:
'USAU', 'GOLD', 'CHNR', 'MPVD', 'OPNT', 'PAAS', 'RGLD', 'SSRM', 'WWR', 
#AIRPLANE STOCKS:
'ALGT', 'AAL', 'HA', 'JBLU', 'MESA', 'RYAAY', 'SKYW', 'SAVE', 'UAL', 'BA'
#MARINE TRANSPORTATION:
'CPLP', 'CTRM', 'EGLE', 'EDRY', 'ESEA', 'GLBS', 'GLNG', 'GOGL', 'GRIN', 'MBUU', 'MCFT', 'NMCI', 'NCLH', 'OMEX', 'PANL', 'DCIX', 'PXS', 
'SHIP', 'SBLK', 'GASS', 'TOPS', 'TRMD'
#AUTO MANUFACTURE:
'APOG', 'CAAS', 'CVGI', 'DORM', 'GNTX', 'THRM', 'IEP', 'MPAA', 'SORL', 'STRT', 'VC',
#CONFERENCING PLATFORMS: 
'ZM', 'CSCO', 'LOGM', 'MSFT', 'GOOGL', 'RNG', 
#BIOTECH STOCKS WORKING ON COVID:
'AMGN', 'ADPT', 'ALT', 'PFE', 'BNTX', 'CYDY', 'GILD', 'GSK', 'HTBX', 'INO', 'JNJ', 'TAK', 'CSLLY', 'TBIO', 'ROG', 'SNY', 'REGN', 
'NVAX', 'MRNA'],
'day', start=start, end=end).df

# %%
stock_list = [
#stocks traded by me and skyrocketing ones.                  
'GE', 'F', 'AMZN', 'TSLA', 'AAPL', 'SNAP', 'GM', 'SHOP', 'TWTR', 'AMD', 'NVDA', 'FB',
#OIL COMPANIES:
'AXAS', 'BRY', 'CRZO', 'CDEV', 'DWSN', 'FANG', 'DMLP', 'EPSN', 'FLMN', 'GPOR', 'LLEX', 'LONE', 'BP',
'MARPS', 'MCEP', 'NEXT', 'PTEN', 'PDCE', 'PVAC', 'PNRG', 'RGCO', 'ROSE', 'SAEX', 'SNDE', 'TELL', 'TRCH', 'TGA', 'USEG', 'VNOM',
#PRECIOUS METALS:
'USAU', 'GOLD', 'CHNR', 'MPVD', 'OPNT', 'PAAS', 'RGLD', 'SSRM', 'WWR', 
#AIRPLANE STOCKS:
'ALGT', 'AAL', 'HA', 'JBLU', 'MESA', 'RYAAY', 'SKYW', 'SAVE', 'UAL', 'BA'
#MARINE TRANSPORTATION:
'CPLP', 'CTRM', 'EGLE', 'EDRY', 'ESEA', 'GLBS', 'GLNG', 'GOGL', 'GRIN', 'MBUU', 'MCFT', 'NMCI', 'NCLH', 'OMEX', 'PANL', 'DCIX', 'PXS', 
'SHIP', 'SBLK', 'GASS', 'TOPS', 'TRMD'
#AUTO MANUFACTURE:
'APOG', 'CAAS', 'CVGI', 'DORM', 'GNTX', 'THRM', 'IEP', 'MPAA', 'SORL', 'STRT', 'VC',
#CONFERENCING PLATFORMS: 
'ZM', 'CSCO', 'LOGM', 'MSFT', 'GOOGL', 'RNG', 
#BIOTECH STOCKS WORKING ON COVID:
'AMGN', 'ADPT', 'ALT', 'PFE', 'BNTX', 'CYDY', 'GILD', 'GSK', 'HTBX', 'INO', 'JNJ', 'TAK', 'CSLLY', 'TBIO', 'ROG', 'SNY', 'REGN', 
'NVAX', 'MRNA']

# %%
import numpy as np
from talib.abstract import *

# %%
inputs = {
    'open': np.random.random(422),
    'high': np.random.random(422),
    'low': np.random.random(422),
    'close': np.random.random(422),
    'volume': np.random.random(422)
}

# %%
#get the metrics to cluster stocks based on them and predict the price move eventually

for i in range (0, 2):
  stock = stock_list[i]

  print(stock)
  stock_df = df[stock]
  stock_df['symbol'] = stock

#relative strength index - a momentum indicator that measures the 
#magnitude of recent price changes in order to evaluate overbought or 
#oversold conditions in the price of a stock or other asset.
  stock_df['rsi'] = 0
  rsi=talib.RSI(np.array(stock_df.close.values,dtype=float),14) 
  stock_df['rsi'] = rsi


#simple moving average - each value in the time period carries equal weight, 
#and values outside of the time period are not included in the average.
  stock_df['sma'] = 0
  sma = talib.SMA(np.array(stock_df.close.values,dtype=float),14)
  stock_df['sma'] = sma

  #exponential moving average - is a cumulative calculation, including all data.
  stock_df['ema'] = 0
  ema = talib.EMA(np.array(stock_df.close.values,dtype=float),14)
  stock_df['ema'] = ema

  stock_df['midpoint'] = 0
  midpoint = talib.MIDPOINT(np.array(stock_df.close.values,dtype=float),14)
  stock_df['midpoint'] = midpoint

  #coomodity channel index -  to determine overbought and oversold levels.
  stock_df['cci'] = 0
  cci = talib.CCI(np.array(stock_df.high.values, dtype=float), np.array(stock_df.low.values, dtype=float), np.array(stock_df.close.values, dtype=float),14)
  stock_df['cci'] = cci

  #On-balance volume, intended to relate price and volume in the stock market. OBV is based on a cumulative total volume
  stock_df['obv'] = 0
  obv = talib.OBV(np.array(stock_df.close.values, dtype=float), np.array(stock_df.volume.values, dtype=float))
  stock_df['obv'] = obv

  #The Balance of Power indicator measures the market strength of buyers against sellers by assessing the ability of each side to drive prices to an extreme level.
  stock_df['bop'] = 0
  bop = talib.BOP(np.array(stock_df.open.values, dtype=float), np.array(stock_df.high.values, dtype=float),  np.array(stock_df.low.values, dtype=float), np.array(stock_df.close.values, dtype=float))
  stock_df['bop'] = bop
  
  #The Money Flow Index (MFI) is a technical indicator that generates overbought or oversold signals using both prices and volume data. 
  #An MFI reading above 80 is considered overbought and an MFI reading below 20 is considered oversold, although levels of 90 and 10 are also used as thresholds
  stock_df['mfi'] = 0
  mfi = talib.MFI(np.array(stock_df.high.values,dtype=float), np.array(stock_df.low.values, dtype=float), np.array(stock_df.close.values, dtype=float), np.array(stock_df.volume.values, dtype=float))
  stock_df['mfi'] = mfi

  '''stock_df['aroon'] = 0
  aroon = talib.AROON(np.array(stock_df.high.values,dtype=float), np.array(stock_df.low.values, dtype=float),14)
  stock_df['aroon'] = aroon'''

  if i == 0:
    df_all = stock_df 
  else: 
    frames = [df_all, stock_df] 
    df_all = pd.concat(frames)
# Out:
# GE
# F
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:50: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:52: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
stock_df.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume', 'symbol', 'rsi', 'sma', 'ema',
#        'midpoint', 'cci', 'obv', 'bop', 'mfi'],
#       dtype='object')

# %%
df_all.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume', 'symbol', 'rsi', 'sma', 'ema',
#        'midpoint', 'cci', 'obv', 'bop', 'mfi'],
#       dtype='object')

# %%
#stochastic oscillator - a trend-following indicator that uses aspects of the Aroon Indicator
#(Aroon Up and Aroon Down) to gauge the strength of a current trend and the likelihood that
#it will continue. 
from talib.abstract import *
slowk, slowd = STOCH(inputs, 5, 3, 0, 3, 0)
print(slowk)
print(slowd)
# Out:
# [         nan          nan          nan          nan          nan
#           nan          nan          nan  65.19006395  84.84260542
#   19.36634382  11.01783098  -6.8942664   18.8495793   55.00958889
#   74.29143005  55.61234628  36.10008287  24.69019176  33.37403765
#   27.48773189  39.91223857  50.06850414  60.1248895   53.37353766
#   74.16736323  45.51549635  54.21757797  30.65002456  60.74237872
#   67.00746963  80.06183784  90.54878622  69.45426985  69.95325778
#   45.39655365  50.45223837  30.99733648  16.17034685  17.98673335
#   36.26119903  39.37507498  25.66348062   9.94763674   6.65659298
#   11.93186313  14.40357855  12.74467915  12.23165696   9.61251662
#   14.37471911  25.41398548  44.58561175  94.14089082 141.7693589
#  183.35048765 154.24467188 107.19169221  60.46487787  42.27947897
#   42.44979005  42.50036759  55.60589642  61.12188196  72.22408242
#   68.01045258  64.40008292  53.74927078  49.15781879  44.47682029
#   32.72819697  33.92860323  43.86031458  62.40563569  69.05099976
#   59.01318287  45.89047951  35.67827003  35.71940879  36.29688203
#   24.60405572  15.00492779  19.82114677  41.76169994  67.16184695
#   74.93938334  72.30523938  62.8352332   54.22395125  54.39628243
#   47.55755356  51.45011126  42.78385135  43.84191086  30.6670894
#   32.95881581  25.13329803  34.98682462  24.93177295  28.28337073
#   20.48435924  34.31179127]

# %%
df_all['slowk'] = slowk.tolist()

df_all['slowd'] = slowd.tolist()

# %%
#df_all.ta.aroon()

# %%
#talib.AROON(df_all.high, df_all.low)

# %%
df_all
# Out:
#                              open    high  ...      slowk      slowd
# time                                       ...
# 2020-01-02 05:00:00+00:00  11.230  11.955  ...        NaN        NaN
# 2020-01-03 05:00:00+00:00  11.570  12.000  ...        NaN        NaN
# 2020-01-06 05:00:00+00:00  11.840  12.210  ...        NaN        NaN
# 2020-01-07 05:00:00+00:00  12.150  12.235  ...        NaN        NaN
# 2020-01-08 05:00:00+00:00  11.990  12.050  ...        NaN        NaN
# ...                           ...     ...  ...        ...        ...
# 2020-10-26 04:00:00+00:00   8.035   8.070  ...  46.181049  34.986825
# 2020-10-27 04:00:00+00:00   8.010   8.090  ...  10.613593  24.931773
# 2020-10-28 04:00:00+00:00   7.680   7.880  ...  28.055470  28.283371
# 2020-10-29 04:00:00+00:00   8.170   8.240  ...  22.784015  20.484359
# 2020-10-30 04:00:00+00:00   7.850   7.910  ...  52.095889  34.311791
#
# [422 rows x 16 columns]

# %%
#copying the df to df_original, to use it when needed, to see the ticker

df_original = df.copy()

# %%
#scaling the stock prices to compare them better with each other.
scaler = StandardScaler()
scaled = scaler.fit_transform(df_original)
df_scaled = pd.DataFrame(scaled, columns=df.columns)
df_scaled.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/extmath.py:765: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/extmath.py:706: RuntimeWarning:
#
# Degrees of freedom <= 0 for slice.
#         AAL                      ...        ZM
#        open      high       low  ...       low     close    volume
# 0  2.185920  2.149186  2.246865  ... -1.156137 -1.177188 -0.927312
# 1  2.070580  1.986652  2.031859  ... -1.162906 -1.186956 -0.944838
# 2  1.895135  1.857287  1.989186  ... -1.172385 -1.165122 -0.782828
# 3  1.955241  1.887999  1.985903  ... -1.146205 -1.153774 -0.444920
# 4  1.898384  1.954306  1.992469  ... -1.133992 -1.149106 -0.832604
#
# [5 rows x 580 columns]

# %%
df_scaled=df_scaled.T.drop_duplicates().T
#dropped the extra 'bop' metric, kept popping up as two separate identical cols in DF.

# %%
df_scaled.dropna().sum()
#dropping nulls from scaled DF
# Out:
# AAL  open      0.0
#      high      0.0
#      low       0.0
#      close     0.0
#      volume    0.0
#               ...
# ZM   open      0.0
#      high      0.0
#      low       0.0
#      close     0.0
#      volume    0.0
# Length: 556, dtype: float64

# %%
df_scaled.isnull().sum() 
# ask REza
# Out:
# AAL  open      0
#      high      0
#      low       0
#      close     0
#      volume    0
#               ..
# ZM   open      2
#      high      2
#      low       2
#      close     2
#      volume    2
# Length: 556, dtype: int64

# %%
df_all.shape
# Out:
# (422, 16)

# %%
df_all
#the metrics I'll use to cluster stocks.
# Out:
#                              open    high  ...      slowk      slowd
# time                                       ...
# 2020-01-02 05:00:00+00:00  11.230  11.955  ...        NaN        NaN
# 2020-01-03 05:00:00+00:00  11.570  12.000  ...        NaN        NaN
# 2020-01-06 05:00:00+00:00  11.840  12.210  ...        NaN        NaN
# 2020-01-07 05:00:00+00:00  12.150  12.235  ...        NaN        NaN
# 2020-01-08 05:00:00+00:00  11.990  12.050  ...        NaN        NaN
# ...                           ...     ...  ...        ...        ...
# 2020-10-26 04:00:00+00:00   8.035   8.070  ...  46.181049  34.986825
# 2020-10-27 04:00:00+00:00   8.010   8.090  ...  10.613593  24.931773
# 2020-10-28 04:00:00+00:00   7.680   7.880  ...  28.055470  28.283371
# 2020-10-29 04:00:00+00:00   8.170   8.240  ...  22.784015  20.484359
# 2020-10-30 04:00:00+00:00   7.850   7.910  ...  52.095889  34.311791
#
# [422 rows x 16 columns]

# %%
df_all.isnull().sum()
# Out:
# open         0
# high         0
# low          0
# close        0
# volume       0
# symbol       0
# rsi         28
# sma         26
# ema         26
# midpoint    26
# cci         26
# obv          0
# bop          0
# mfi         28
# slowk        8
# slowd        8
# dtype: int64

# %%
df_all = df_all.dropna()
#dropped nulls

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 394 entries, 2020-01-23 05:00:00+00:00 to 2020-10-30 04:00:00+00:00
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   open      394 non-null    float64
#  1   high      394 non-null    float64
#  2   low       394 non-null    float64
#  3   close     394 non-null    float64
#  4   volume    394 non-null    int64
#  5   symbol    394 non-null    object
#  6   rsi       394 non-null    float64
#  7   sma       394 non-null    float64
#  8   ema       394 non-null    float64
#  9   midpoint  394 non-null    float64
#  10  cci       394 non-null    float64
#  11  obv       394 non-null    float64
#  12  bop       394 non-null    float64
#  13  mfi       394 non-null    float64
#  14  slowk     394 non-null    float64
#  15  slowd     394 non-null    float64
# dtypes: float64(14), int64(1), object(1)
# memory usage: 52.3+ KB

# %%
keep_cols = ['close', 'volume', 'rsi', 'sma', 'ema', 'midpoint', 'slowk', 'slowd', 'bop',	'cci', 'obv']
df_all=df_all[keep_cols]
df_all.head()
# Out:
#                            close     volume  ...         cci          obv
# time                                         ...
# 2020-01-23 05:00:00+00:00  11.78  117996965  ...  -64.571379  -80112924.0
# 2020-01-24 05:00:00+00:00  11.71   97879433  ...  -58.592081 -177992357.0
# 2020-01-27 05:00:00+00:00  11.44   39002015  ... -152.233372 -216994372.0
# 2020-01-28 05:00:00+00:00  11.73   52000062  ...  -53.634085 -164994310.0
# 2020-01-29 05:00:00+00:00  12.94  183721982  ...  303.807490   18727672.0
#
# [5 rows x 11 columns]

# %%
df_all.corr()
#correlation check
# Out:
#              close    volume       rsi  ...       bop       cci       obv
# close     1.000000 -0.295177  0.127696  ...  0.024761  0.055982  0.473069
# volume   -0.295177  1.000000  0.195810  ...  0.022335  0.193718 -0.431182
# rsi       0.127696  0.195810  1.000000  ...  0.266995  0.824189  0.131458
# sma       0.939659 -0.356307 -0.157024  ... -0.067190 -0.215376  0.449849
# ema       0.953698 -0.355052 -0.130849  ... -0.061825 -0.177124  0.455491
# midpoint  0.945742 -0.350442 -0.134908  ... -0.065344 -0.193682  0.450694
# slowk    -0.040358  0.040250  0.035884  ... -0.049031  0.021138 -0.060860
# slowd    -0.056060  0.012496  0.024410  ... -0.055026 -0.007707 -0.067789
# bop       0.024761  0.022335  0.266995  ...  1.000000  0.263144  0.043586
# cci       0.055982  0.193718  0.824189  ...  0.263144  1.000000  0.102201
# obv       0.473069 -0.431182  0.131458  ...  0.043586  0.102201  1.000000
#
# [11 rows x 11 columns]

# %%
#let's use the visuals - the heatmap to see the correlation
plt.figure(figsize=(12, 10))
sns.heatmap(df_all.corr(), vmin=-1, vmax=1, annot=True)
plt.show()

# %%
#close price and ema are highly correlated, will take the difference and create a new column for it
dif_close_ema = df_all['close'] - df_all['ema']
dif_close_ema
#one common col to add for df_all
# Out:
# time
# 2020-01-23 05:00:00+00:00   -0.083881
# 2020-01-24 05:00:00+00:00   -0.133363
# 2020-01-27 05:00:00+00:00   -0.349582
# 2020-01-28 05:00:00+00:00   -0.051637
# 2020-01-29 05:00:00+00:00    1.003914
#                                ...
# 2020-10-26 04:00:00+00:00    0.327577
# 2020-10-27 04:00:00+00:00    0.188566
# 2020-10-28 04:00:00+00:00   -0.009909
# 2020-10-29 04:00:00+00:00    0.147412
# 2020-10-30 04:00:00+00:00   -0.024256
# Length: 394, dtype: float64

# %%
slow_k_d = df_all['slowk'] - df_all['slowd']
slow_k_d
#100% correlated, creating one new common column from their difference and will drop them both afterwards.
# Out:
# time
# 2020-01-23 05:00:00+00:00    32.687955
# 2020-01-24 05:00:00+00:00    24.907897
# 2020-01-27 05:00:00+00:00    -6.025442
# 2020-01-28 05:00:00+00:00   -19.234537
# 2020-01-29 05:00:00+00:00   -14.110682
#                                ...
# 2020-10-26 04:00:00+00:00    11.194224
# 2020-10-27 04:00:00+00:00   -14.318180
# 2020-10-28 04:00:00+00:00    -0.227900
# 2020-10-29 04:00:00+00:00     2.299655
# 2020-10-30 04:00:00+00:00    17.784098
# Length: 394, dtype: float64

# %%
#adding the new cols to the DF
df_all['slow_k_d'] = slow_k_d.tolist()
df_all['dif_close_ema'] = dif_close_ema.tolist()

# %%
df_all
# Out:
#                              close     volume  ...   slow_k_d  dif_close_ema
# time                                           ...
# 2020-01-23 05:00:00+00:00  11.7800  117996965  ...  32.687955      -0.083881
# 2020-01-24 05:00:00+00:00  11.7100   97879433  ...  24.907897      -0.133363
# 2020-01-27 05:00:00+00:00  11.4400   39002015  ...  -6.025442      -0.349582
# 2020-01-28 05:00:00+00:00  11.7300   52000062  ... -19.234537      -0.051637
# 2020-01-29 05:00:00+00:00  12.9400  183721982  ... -14.110682       1.003914
# ...                            ...        ...  ...        ...            ...
# 2020-10-26 04:00:00+00:00   8.0300  114570938  ...  11.194224       0.327577
# 2020-10-27 04:00:00+00:00   7.9200  122673015  ... -14.318180       0.188566
# 2020-10-28 04:00:00+00:00   7.7200  132221960  ...  -0.227900      -0.009909
# 2020-10-29 04:00:00+00:00   7.9000  213762582  ...   2.299655       0.147412
# 2020-10-30 04:00:00+00:00   7.7246  145771133  ...  17.784098      -0.024256
#
# [394 rows x 13 columns]

# %%
#still see some leftover correlations, let's drop them too
drop_cols = ['ema', 'midpoint', 'slowk', 'slowd', 'close', 'cci', 'rsi']
df_all.drop(drop_cols, axis = 1, inplace=True)
df_all.head()
# Out:
#                               volume        sma  ...   slow_k_d  dif_close_ema
# time                                             ...
# 2020-01-23 05:00:00+00:00  117996965  11.865357  ...  32.687955      -0.083881
# 2020-01-24 05:00:00+00:00   97879433  11.846786  ...  24.907897      -0.133363
# 2020-01-27 05:00:00+00:00   39002015  11.796786  ...  -6.025442      -0.349582
# 2020-01-28 05:00:00+00:00   52000062  11.773571  ... -19.234537      -0.051637
# 2020-01-29 05:00:00+00:00  183721982  11.845714  ... -14.110682       1.003914
#
# [5 rows x 6 columns]

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df_all.corr(), vmin=-1, vmax=1, annot=True)
plt.show()
#I want to keep the rsi

# %%
df_all.shape
# Out:
# (394, 6)

# %%
#!pip install yellowbrick

# %%
#scaling the data to make them all equal on one scale.
scaler = StandardScaler()
scaled = scaler.fit_transform(df_all)

df_scaled = pd.DataFrame(scaled, columns=df_all.columns)
df_scaled.head()
# Out:
#      volume       sma       bop       obv  slow_k_d  dif_close_ema
# 0 -0.157791  2.647030  0.548253  1.276099  1.654170       0.032773
# 1 -0.432141  2.636611 -1.002033  1.168466  1.259831      -0.060843
# 2 -1.235076  2.608559  0.089409  1.125578 -0.308052      -0.469903
# 3 -1.057816  2.595535  1.306624  1.182760 -0.977567       0.093774
# 4  0.738527  2.636010  1.542235  1.384789 -0.717860       2.090757

# %%
df_scaled.columns
# Out:
# Index(['volume', 'sma', 'bop', 'obv', 'slow_k_d', 'dif_close_ema'], dtype='object')

# %%
y = df_scaled['dif_close_ema'] #the prediction value
X = df_scaled.drop(columns=['dif_close_ema']) #the features to predict the value

# %%
X
# Out:
#        volume       sma       bop       obv  slow_k_d
# 0   -0.157791  2.647030  0.548253  1.276099  1.654170
# 1   -0.432141  2.636611 -1.002033  1.168466  1.259831
# 2   -1.235076  2.608559  0.089409  1.125578 -0.308052
# 3   -1.057816  2.595535  1.306624  1.182760 -0.977567
# 4    0.738527  2.636010  1.542235  1.384789 -0.717860
# ..        ...       ...       ...       ...       ...
# 389 -0.204513  0.307120  0.107899  1.493866  0.564742
# 390 -0.094022  0.334370 -0.709242  1.358968 -0.728377
# 391  0.036201  0.349197  0.480515  1.213571 -0.014199
# 392  1.148202  0.375446 -1.119712  1.448634  0.113913
# 393  0.220976  0.377433 -0.604693  1.288337  0.898755
#
# [394 rows x 5 columns]

# %%
y
#the prediction value in a scaled version
# Out:
# 0      0.032773
# 1     -0.060843
# 2     -0.469903
# 3      0.093774
# 4      2.090757
#          ...
# 389    0.811203
# 390    0.548212
# 391    0.172719
# 392    0.470353
# 393    0.145576
# Name: dif_close_ema, Length: 394, dtype: float64

# %%
#getting the elbow plot to see what might be the right number of clusters

distortions = [] 
inertias = [] 
mapping1 = {} 
mapping2 = {} 
K = range(1,20)

for k in K: #Building and fitting the model kmeanModel = KMeans(n_clusters=k).fit(X) kmeanModel.fit(X)
    kmeanModel = KMeans(n_clusters=k).fit(X) 
    kmeanModel.fit(X)

    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_, 
                  'euclidean'),axis=1)) / X.shape[0]) 
    inertias.append(kmeanModel.inertia_) 

    mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_, 
             'euclidean'),axis=1)) / X.shape[0] 
    mapping2[k] = kmeanModel.inertia_

# %%
plt.plot(K, distortions, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Distortion') 
plt.title('The Elbow Method using Distortion') 
plt.show()

#can see the change between 5 and 7.5

# %% [markdown]
# 5 clusters:

# %%
kmeans = KMeans(n_clusters = 10, random_state=55)
kmeans.fit(X)
y_pred = kmeans.predict(X)
print(y_pred)
# Out:
# [4 4 8 8 8 4 4 4 8 8 8 4 8 4 8 4 4 4 4 4 4 8 4 8 8 8 4 4 8 8 8 8 8 4 5 5 1
#  7 7 7 1 1 7 7 7 1 7 7 1 1 1 5 5 7 3 3 0 0 0 9 0 6 2 3 0 6 9 9 9 0 0 0 0 6
#  6 3 0 9 9 0 9 0 6 6 2 0 9 0 0 6 6 6 6 0 9 0 0 0 2 6 3 2 5 5 2 2 2 6 2 6 6
#  2 5 2 2 6 2 6 2 6 6 2 2 2 6 6 2 2 2 6 0 0 0 0 5 6 3 6 6 3 3 2 5 2 2 2 2 6
#  6 2 2 2 6 0 3 6 0 0 0 0 0 2 6 2 9 9 2 3 2 2 2 6 3 2 5 5 6 3 0 5 6 0 3 2 6
#  6 9 0 0 5 6 0 0 0 9 0 6 7 1 7 7 1 7 7 7 7 1 1 1 1 7 7 7 1 1 1 7 1 1 1 1 1
#  7 5 5 1 1 1 1 7 3 2 1 2 3 3 5 2 3 6 3 2 6 5 5 3 3 3 0 3 5 9 0 3 3 2 0 5 2
#  2 6 3 6 0 0 0 2 3 3 0 5 5 2 3 0 6 6 6 6 5 5 5 0 3 3 3 6 3 7 7 9 7 7 0 5 1
#  7 1 1 7 1 7 1 1 7 1 7 7 1 1 7 1 1 1 7 1 7 7 7 1 1 1 7 7 1 7 7 1 7 3 7 1 7
#  7 7 7 7 1 7 7 1 1 1 7 1 5 5 1 3 3 1 7 7 1 7 7 1 1 7 7 1 1 7 1 1 1 1 7 1 7
#  1 7 7 7 7 1 7 7 1 7 7 1 7 1 1 7 7 7 1 7 1 7 1 1]

# %%
pca = PCA(n_components=5).fit_transform(X)

plt.figure(figsize=(10,7))
colours = 'rbgymrck'
plt.scatter(pca[:, 0], pca[:, 1], c=y_pred, s=50, cmap='viridis')

plt.xticks([])
plt.yticks([])
plt.axis('off')
plt.show()

# %%
from sklearn import datasets, metrics
print(metrics.silhouette_score(X, y_pred, metric='euclidean')) 
#silhouette score gave the best result at number of clusters = 7, from 2 to 6 performed poorly.
# Out:
# 0.23679602961052584

# %%
pd.Series(kmeans.labels_).value_counts()
# Out:
# 7    74
# 1    72
# 0    47
# 6    45
# 2    44
# 3    35
# 5    28
# 8    17
# 4    17
# 9    15
# dtype: int64

# %%
df_scaled['label'] = kmeans.labels_ #0-4(changable) above clusters #adding a label to a df
df_scaled['label'] = df_scaled['label'].astype(str)

# %%
centroids = df_scaled.groupby(['label']).mean() #grouping by label, shows avg

# %%
centroids.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_a76b625e_2fab_11eb_92d3_0242ac1c0002row0_col0,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row5_col2{
#             background-color:  #4a98c5;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row0_col1,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row2_col2{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row0_col2{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row0_col3{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row0_col4{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row0_col5{
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row1_col0{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row1_col1,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row3_col2,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row8_col4{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row1_col2,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row2_col3,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row3_col1,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row3_col4,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row4_col0,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row8_col5{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row1_col3{
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row1_col4{
#             background-color:  #96b6d7;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row1_col5{
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row2_col0{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row2_col1,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row5_col1{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row2_col4{
#             background-color:  #88b1d4;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row2_col5{
#             background-color:  #a1bbda;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row3_col0{
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row3_col3{
#             background-color:  #c9cee4;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row3_col5,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row7_col4{
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row4_col1,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row4_col3,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row5_col4,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row6_col2,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row9_col0,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row9_col5{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row4_col2{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row4_col4{
#             background-color:  #4c99c5;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row4_col5{
#             background-color:  #97b7d7;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row5_col0{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row5_col3{
#             background-color:  #b7c5df;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row5_col5{
#             background-color:  #b4c4df;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row6_col0,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row6_col4{
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row6_col1{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row6_col3{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row6_col5{
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row7_col0{
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row7_col1{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row7_col2{
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row7_col3{
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row7_col5{
#             background-color:  #348ebf;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row8_col0{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row8_col1{
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row8_col2{
#             background-color:  #509ac6;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row8_col3{
#             background-color:  #03446a;
#             color:  #f1f1f1;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row9_col1,#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row9_col3{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row9_col2{
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }#T_a76b625e_2fab_11eb_92d3_0242ac1c0002row9_col4{
#             background-color:  #529bc7;
#             color:  #000000;
#         }</style><table id="T_a76b625e_2fab_11eb_92d3_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >volume</th>        <th class="col_heading level0 col1" >sma</th>        <th class="col_heading level0 col2" >bop</th>        <th class="col_heading level0 col3" >obv</th>        <th class="col_heading level0 col4" >slow_k_d</th>        <th class="col_heading level0 col5" >dif_close_ema</th>    </tr>    <tr>        <th class="index_name level0" >label</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a76b625e_2fab_11eb_92d3_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a76b625e_2fab_11eb_92d3_0242ac1c0002row0_col0" class="data row0 col0" >1.255029</td>
#                         <td id="T_a76b625e_2fab_11eb_92d3_0242ac1c0002row0_col1" class="data row0 col1" >-0.444768</td>
#                         <td id="T_a76b625e_2fab_11eb_92d3_0242ac1c0002row0_col2" class="data row0 col2" >-0.778069</td>
#                         <td id="T_a76b625e_2fab_11eb_92d3_0242ac1c0002row0_col3" class="data row0 col3" >-0.966792</td>
#                         <td id="T_a76b625e_2fab_11eb_92d3_0242ac1c0002row0_col4" class="data row0 col4" >0.276671</td>
#                         <td id="T_a76b625e_2fab_11eb_92d3_0242ac1c0002row0_col5" class="data row0 col5" >0.116184</td>
#             </tr>
#             <tr>
#                         <th id="T_a76b625e_2fab_11eb_92d3_0242ac1c0002level0_row1" clas

# %%
df_original[df_scaled['label'] == '1']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-61-b17601502d04> in <module>()
# ----> 1 df_original[df_scaled['label'] == '1']
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2895         # Do we have a (boolean) 1d indexer?
#    2896         if com.is_bool_indexer(key):
# -> 2897             return self._getitem_bool_array(key)
#    2898
#    2899         # We are left with two options: a single key, and a collection of keys,
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2947         # check_bool_indexer will throw exception if Series key cannot
#    2948         # be reindexed to match DataFrame rows
# -> 2949         key = check_bool_indexer(self.index, key)
#    2950         indexer = key.nonzero()[0]
#    2951         return self._take_with_is_copy(indexer, axis=0)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in check_bool_indexer(index, key)
#    2181         if mask.any():
#    2182             raise IndexingError(
# -> 2183                 "Unalignable boolean Series provided as "
#    2184                 "indexer (index of the boolean Series and of "
#    2185                 "the indexed object do not match)."
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

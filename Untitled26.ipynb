# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaukhar-ai/Capstone/blob/master/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install alpaca-trade-api --quiet
# !pip install pandas-ta --quiet
# Out:
#      |████████████████████████████████| 204kB 6.5MB/s
#      |████████████████████████████████| 81kB 5.0MB/s
#      |████████████████████████████████| 81kB 3.6MB/s
# ...

# %%
import alpaca_trade_api as tradeapi
import pandas as pd
import pandas_ta as ta


api = tradeapi.REST(key_id='PK4MC4MS4RI64GOEK0Y3', 
                    secret_key='Nt2HbEvo0aoozI5cS22sggRnSKmv22dB1wVVAEZo', 
                    base_url='https://paper-api.alpaca.markets')

# %%
# Get a list of all active assets.
active_assets = api.list_assets(status='active')

# Filter the assets down to just those on NASDAQ.
nasdaq_assets = [a for a in active_assets if a.exchange == 'NASDAQ']
for i in nasdaq_assets:
    print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
#     'status': 'active',
#     'symbol': 'TCF',
#     'tradable': True})
# Asset({   'class': 'us_equity',
#     'easy_to_borrow': True,
#     'exchange': 'NASDAQ',
#     'id': 'f211d35f-8d4c-473b-a8c2-c6dc2b79e42b',
#     'marginable': True,
#     'name': 'The Community Financial Corporation Common Stock',
#     'shortable': True,
#     'status': 'active',
#     'symbol': 'TCFC',
#     'tradable': True})
# Asset({   'class': 'us_equity',
#     'easy_to_borrow': False,
#     'exchange': 'NASDAQ',
#     'id': 'aa4c9020-0278-41db-b7a2-74218240e07d',
#     'marginable': True,
#     'name': 'TCF Financial Corporation Depositary Shares representing 5.70% '
#             'Series C Non-Cumulative Preferred Stock',
#     'shortable': False,
#     'status': 'active',
#     'symbol': 'TCFCP',
#     'tradable': True})
# Asset({   'class': 'us_equity',
#     'easy_to_borrow': True,
#     'exchange': 'NASDAQ',
# ...

# %%
stockUniverse = []

# %%
# Get daily price data for AAPL over the last 100 trading days.
barset = api.get_barset('AAPL', 'day', limit=100)
aapl_bars = barset['AAPL']

# See how much AAPL moved in that timeframe. VOLUME
week_open = aapl_bars[0].o
week_close = aapl_bars[-1].c
percent_change = (week_close - week_open) / week_open
print('AAPL moved {}% over the last 5 days'.format(percent_change))
# Out:
# AAPL moved -0.6810656517602284% over the last 5 days

# %%
df = api.get_barset('GE', 'day', limit=100).df

# %%
df.head()
# Out:
#                              GE
#                            open  high   low close    volume
# time
# 2020-07-02 00:00:00-04:00  6.86  7.04  6.81  6.82  68852200
# 2020-07-06 00:00:00-04:00  6.98  7.08  6.89  7.00  68903184
# 2020-07-07 00:00:00-04:00  6.89  6.89  6.75  6.76  58777149
# 2020-07-08 00:00:00-04:00  6.82  6.87  6.72  6.86  57766792
# 2020-07-09 00:00:00-04:00  6.83  6.83  6.58  6.58  70824523

# %%
stockUniverse =

# %%
df['VWAP'] = df.ta.vwap(high='high', low='low', close='close', volume='volume')
df['NATR'] = df.ta.natr(length=14, high='high', low='low', close='close')

# %%
#REZA, THE SCRAPING STARTS HERE. LMK IF I CAN SOMEHOW EXTRACT IT FROM NASDAQ DIRECTLY?

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
company_ticker = []

# %%
URL = 'https://topforeignstocks.com/stock-lists/the-complete-list-of-oil-and-gas-producers-stocks-trading-on-nasdaq/'
page = requests.get(URL)
soup = BeautifulSoup(page.text, 'html.parser')
odd_rows = soup.find_all('td', attrs={'class': 'column-3'})

# %%
odd_rows
# Out:
# [<td class="column-3"><a href="http://finance.yahoo.com/q?s=AXAS">AXAS</a></td>,
#  <td class="column-3"><a href="http://finance.yahoo.com/q?s=BRY">BRY</a></td>,
#  <td class="column-3"><a href="http://finance.yahoo.com/q?s=CRZO">CRZO</a></td>,
#  <td class="column-3"><a href="http://finance.yahoo.com/q?s=CDEV">CDEV</a></td>,
#  <td class="column-3"><a href="http://finance.yahoo.com/q?s=DWSN">DWSN</a></td>,
#  <td class="column-3"><a href="http://finance.yahoo.com/q?s=FANG">FANG</a></td>,
#  <td class="column-3"><a href="http://finance.yahoo.com/q?s=DMLP">DMLP</a></td>,
#  <td class="column-3"><a href="http://finance.yahoo.com/q?s=EPSN">EPSN</a></td>,
#  <td class="column-3"><a href="http://finance.yahoo.com/q?s=XOG">XOG</a></td>,
#  <td class="column-3"><a href="http://finance.yahoo.com/q?s=FLMN">FLMN</a></td>,
#  <td class="column-3"><a href="http://finance.yahoo.com/q?s=GPOR">GPOR</a></td>,
#  <td class="column-3"><a href="http://finance.yahoo.com/q?s=LLEX">LLEX</a></td>,
# ...

# %%
for i in odd_rows:
  row = i.find_all('td')
  print(row[0])
 #company_ticker.append(row['column-3'].text.strip())

# %%
company_ticker
# Out:
# []

# %%
company_ticker.append(row[0].text.strip())
  company_ticker.append(row['column-3'].text.strip())

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US" prefix="" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-129064405-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-129064405-1');
# </script>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-11539341-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-11539341-1');
# </script>
# <meta charset="utf-8"/>
# <meta content="width=device-width" name="viewport"/>
# <title>The Complete List of Oil and Gas Producers Stocks Trading on NASDAQ | TopForeignStocks.com</title>
# ...
